# %% [markdown]
# Pandas Time Series
#
# we can find out the data within a cetain range of data and time by using pandas module named Time series

# %% [markdown]
# - Equivalent to data time python package
#
# - Used to deal with data time
#
# - Complex operation on data can be done

# %% [markdown]
# TimeStamp
#
# 21-jan-2021
#
# 21-01-2021
#
# 21-01-21
#
# 21-01-2021 30:12:11

# %%
data = '15-january-2023'

# %%
type(data)
# Out:
# str

# %%
import pandas as pd

dt = pd.to_datetime(data,format='%d-%B-%Y')

# %%
dt
# Out:
# Timestamp('2023-01-15 00:00:00')

# %%
type(dt)
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
# %d --- 01,25,65
# %B --- january,march
# %b --- jsn,mar,flexible
# %m --- int(month in integer)
# Out:
# UsageError: Line magic function `%d` not found.

# %%
# %y --- 20,21
# %Y --- 2021,int
# %H --- 24 hr
# %I --- 12 hr
# %M --- Minute
# %S --- seconds

# %%
dates = ['2020-02-13 2:55:07 PM','05 jan 2021 21:07:00','01/04/2020','2020.03.07','2020/07/08','20201106']

import pandas as pd

date_time = pd.to_datetime(dates)

date_time
# Out:
# <ipython-input-15-21c754ac1916>:5: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   date_time = pd.to_datetime(dates)
# DatetimeIndex(['2020-02-13 14:55:07', '2021-01-05 21:07:00',
#                '2020-01-04 00:00:00', '2020-03-07 00:00:00',
#                '2020-07-08 00:00:00', '2020-11-06 00:00:00'],
#               dtype='datetime64[ns]', freq=None)

# %%
import pandas as pd

dates = '27 - sep - 24'

date_time = pd.to_datetime(dates)

print(date_time)

print(date_time.day)

print(date_time.week)
print(date_time.day_of_week)
print(date_time.dayofyear)
print(date_time.minute)
print(date_time.is_leap_year)
print(date_time.is_month_end)
print(date_time.is_month_start)
print(date_time.month)

print(date_time.quarter)
# Out:
# 2024-09-27 00:00:00
# 27
# 39
# 4
# 271
# 0
# True
# False
# False
# 9
# 3

# %%
import pandas as pd

df = pd.read_csv('/content/drive/MyDrive/python/LIBRARIES/PANDAS/student.csv')

# %%
df
# Out:
#     Unnamed: 0  id    Name subject_id  Marks_scored  roll no  class
# 0            1   1   Billy       sub2            89      1.0    NaN
# 1            2   2   Brian       sub4            80     23.0    NaN
# 2            3   3    Bran       sub3            79      4.0    NaN
# 3            4   4   Bryce       sub6            97      5.0    NaN
# 4            5   5   Betty       sub5            88      5.0    NaN
# 5            6   6  sarang       sub7            76      6.0    NaN
# 6            1   1   Billy       sub2            89      NaN    1.0
# 7            2   2   Brian       sub4            80      NaN   23.0
# 8            3   3    Bran       sub8            79      NaN    4.0
# 9            4   4   Bryce       sub6            97      NaN    5.0
# 10           5   5   Betty       sub5            88      NaN    5.0
# 11           7   7    ramu       sub9            56      NaN    6.0

# %%
df.head(3)
# Out:
#    Unnamed: 0  id   Name subject_id  Marks_scored  roll no  class
# 0           1   1  Billy       sub2            89      1.0    NaN
# 1           2   2  Brian       sub4            80     23.0    NaN
# 2           3   3   Bran       sub3            79      4.0    NaN

# %%
df.tail(6)
# Out:
#     Unnamed: 0  id   Name subject_id  Marks_scored  roll no  class
# 6            1   1  Billy       sub2            89      NaN    1.0
# 7            2   2  Brian       sub4            80      NaN   23.0
# 8            3   3   Bran       sub8            79      NaN    4.0
# 9            4   4  Bryce       sub6            97      NaN    5.0
# 10           5   5  Betty       sub5            88      NaN    5.0
# 11           7   7   ramu       sub9            56      NaN    6.0

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import pandas as pd

df = pd.read_csv('/contentANDAS/shirpurGoldRefinery (1) (2).csv/drive/MyDrive/python/LIBRARIES/P')

# %%
df
# Out:
#                  Date  Open Price  High Price  Low Price  Close Price  \
# 0    29-December-2017      203.55       206.5     201.00       201.85
# 1    28-December-2017      202.00       207.6     199.55       202.80
# 2    27-December-2017      209.10       213.6     195.20       197.80
# 3    26-December-2017      216.50       219.9     207.20       209.70
# 4    22-December-2017      218.95       233.6     212.40       218.15
# ..                ...         ...         ...        ...          ...
# 243    6-January-2017      110.10       110.1     107.80       110.10
# 244    5-January-2017      101.00       104.9     100.00       104.90
# 245    4-January-2017       99.50       102.0      99.50        99.95
# 246    3-January-2017      102.00       102.0     100.05       100.65
# 247    2-January-2017      104.00       104.0      99.00       101.65
#
#             WAP  No.of Shares  No. of Trades  Total Turnover (Rs.)  \
# ...

# %%
df.head(2)
# Out:
#                Date  Open Price  High Price  Low Price  Close Price  \
# 0  29-December-2017      203.55       206.5     201.00       201.85
# 1  28-December-2017      202.00       207.6     199.55       202.80
#
#           WAP  No.of Shares  No. of Trades  Total Turnover (Rs.)  \
# 0  202.760380          3372             68              683708.0
# 1  203.118439          8612            196             1749256.0
#
#    Deliverable Quantity  % Deli. Qty to Traded Qty  Spread High-Low  \
# 0                  2202                      65.30             5.50
# 1                  5063                      58.79             8.05
#
#    Spread Close-Open
# 0               -1.7
# 1                0.8

# %%
df.iat[0,0]
# Out:
# '29-December-2017'

# %%
type(df.iat[0,0])
# Out:
# str

# %%
df['TimeStamp']=pd.to_datetime(df['Date'])

# %%
df.head(2)
# Out:
#                Date  Open Price  High Price  Low Price  Close Price  \
# 0  29-December-2017      203.55       206.5     201.00       201.85
# 1  28-December-2017      202.00       207.6     199.55       202.80
#
#           WAP  No.of Shares  No. of Trades  Total Turnover (Rs.)  \
# 0  202.760380          3372             68              683708.0
# 1  203.118439          8612            196             1749256.0
#
#    Deliverable Quantity  % Deli. Qty to Traded Qty  Spread High-Low  \
# 0                  2202                      65.30             5.50
# 1                  5063                      58.79             8.05
#
#    Spread Close-Open  TimeStamp
# 0               -1.7 2017-12-29
# 1                0.8 2017-12-28

# %%
df.iat[0,13]
# Out:
# Timestamp('2017-12-29 00:00:00')

# %%
type(df.iat[0,13])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
df['Date']=pd.to_datetime(df['Date'])

# %%
df
# Out:
#           Date  Open Price  High Price  Low Price  Close Price         WAP  \
# 0   2017-12-29      203.55       206.5     201.00       201.85  202.760380
# 1   2017-12-28      202.00       207.6     199.55       202.80  203.118439
# 2   2017-12-27      209.10       213.6     195.20       197.80  202.801825
# 3   2017-12-26      216.50       219.9     207.20       209.70  213.418007
# 4   2017-12-22      218.95       233.6     212.40       218.15  223.089049
# ..         ...         ...         ...        ...          ...         ...
# 243 2017-01-06      110.10       110.1     107.80       110.10  110.048719
# 244 2017-01-05      101.00       104.9     100.00       104.90  103.352347
# 245 2017-01-04       99.50       102.0      99.50        99.95  100.293226
# 246 2017-01-03      102.00       102.0     100.05       100.65  100.784909
# 247 2017-01-02      104.00       104.0      99.00       101.65  101.302024
#
# ...

# %%
df.TimeStamp
# Out:
# 0     2017-12-29
# 1     2017-12-28
# 2     2017-12-27
# 3     2017-12-26
# 4     2017-12-22
#          ...
# 243   2017-01-06
# 244   2017-01-05
# 245   2017-01-04
# 246   2017-01-03
# 247   2017-01-02
# Name: TimeStamp, Length: 248, dtype: datetime64[ns]

# %%
df.TimeStamp.max()
# Out:
# Timestamp('2017-12-29 00:00:00')

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('/content/drive/MyDrive/python/LIBRARIES/PANDAS/shirpurGoldRefinery (1) (2).csv')

# %%
df.head()
# Out:
#                Date  Open Price  High Price  Low Price  Close Price  \
# 0  29-December-2017      203.55       206.5     201.00       201.85
# 1  28-December-2017      202.00       207.6     199.55       202.80
# 2  27-December-2017      209.10       213.6     195.20       197.80
# 3  26-December-2017      216.50       219.9     207.20       209.70
# 4  22-December-2017      218.95       233.6     212.40       218.15
#
#           WAP  No.of Shares  No. of Trades  Total Turnover (Rs.)  \
# 0  202.760380          3372             68              683708.0
# 1  203.118439          8612            196             1749256.0
# 2  202.801825         24983            426             5066598.0
# 3  213.418007         17782            363             3794999.0
# 4  223.089049        165976           2710            37027428.0
#
#    Deliverable Quantity  % Deli. Qty to Traded Qty  Spread High-Low  \
# 0                  2202                      65.30             5.50
# ...

# %%
df['Date']= pd.to_datetime(df['Date'],format = '%d-%B-%Y')

# %%
df.head(2)
# Out:
#         Date  Open Price  High Price  Low Price  Close Price         WAP  \
# 0 2017-12-29      203.55       206.5     201.00       201.85  202.760380
# 1 2017-12-28      202.00       207.6     199.55       202.80  203.118439
#
#    No.of Shares  No. of Trades  Total Turnover (Rs.)  Deliverable Quantity  \
# 0          3372             68              683708.0                  2202
# 1          8612            196             1749256.0                  5063
#
#    % Deli. Qty to Traded Qty  Spread High-Low  Spread Close-Open
# 0                      65.30             5.50               -1.7
# 1                      58.79             8.05                0.8

# %%
df['day'] = pd.DatetimeIndex(df['Date']).day
df['year'] = pd.DatetimeIndex(df['Date']).year
df['month'] = pd.DatetimeIndex(df['Date']).month

# %%
df.head()
# Out:
#         Date  Open Price  High Price  Low Price  Close Price         WAP  \
# 0 2017-12-29      203.55       206.5     201.00       201.85  202.760380
# 1 2017-12-28      202.00       207.6     199.55       202.80  203.118439
# 2 2017-12-27      209.10       213.6     195.20       197.80  202.801825
# 3 2017-12-26      216.50       219.9     207.20       209.70  213.418007
# 4 2017-12-22      218.95       233.6     212.40       218.15  223.089049
#
#    No.of Shares  No. of Trades  Total Turnover (Rs.)  Deliverable Quantity  \
# 0          3372             68              683708.0                  2202
# 1          8612            196             1749256.0                  5063
# 2         24983            426             5066598.0                 14168
# 3         17782            363             3794999.0                  7540
# 4        165976           2710            37027428.0                 60121
#
# ...
